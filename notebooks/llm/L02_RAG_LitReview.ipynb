# %% [markdown]
# # L02 — RAG for Economics Literature Review

# %% [markdown]
# ## 0. Overview
# | | |
# |---|---|
# | **Backend** | GPT-4o + text-embedding-3-small + FAISS |
# | **Use case** | Q&A over local PDF library of economics papers |
# | **This notebook** | Build a RAG pipeline over arXiv econ papers |

# %% [markdown]
# ---
# ## 3. Setup & Ingest (coming in v0.3)

# %%
# pip install openai faiss-cpu pypdf2 langchain
# from empirlab.llm import LitReviewRAG

# rag = LitReviewRAG(llm='gpt-4o')
# rag.ingest(pdf_paths=['chernozhukov2018.pdf', 'wager_athey2018.pdf'])
print('LitReviewRAG coming in empirlab v0.3')

# %% [markdown]
# ---
# ## 4. Querying

# %%
# answer = rag.query('What is the key identification assumption in DML?')
# print(answer)

# %% [markdown]
# ---
# ## 6. Example Output

# %%
example_q = 'What is the key identification assumption in DML?'
example_a = (
    'The key assumption is Neyman orthogonality: the moment condition '
    'used to identify theta is insensitive (to first order) to perturbations '
    'in the nuisance parameters g and m. This, combined with cross-fitting, '
    'eliminates regularisation bias from ML nuisance estimation.'
)
print(f'Q: {example_q}')
print(f'A: {example_a}')
